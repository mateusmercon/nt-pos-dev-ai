# %% [markdown]
# <a href="https://colab.research.google.com/github/mateusmercon/nt-pos-dev-ai/blob/main/Lista_1_NT_POS_DEV_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho de Introdução ao Pré-processamento de Dados com Pandas - Parte 1
#
# Aluno: Mateus Neves Merçon

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercício 1

# %% [markdown]
# ### a) Carregue o dataset em um DataFrame do Pandas.

# %%
df = pd.read_csv("https://w.infojurclientes.com.br/Covid_Data.csv")

# %% [markdown]
# ### b) Verifique a quantidade de linhas e colunas presentes no dataset.

# %%
print("Shape do dataframe (linhas, colunas):",df.shape)
# Out:
# Shape do dataframe (linhas, colunas): (1048575, 21)

# %% [markdown]
# ### c) Exiba as primeiras 3 (três) linhas do DataFrame para entender a estrutura dos dados.

# %%
df.head(3)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU
# 0               2        2              2        2                     3   97
# 1               2        1              1        2                     5   97
# 2               2        2              2        2                     3    2
#
# [3 rows x 21 columns]

# %% [markdown]
# ### d) Exiba as útimas 4 (quatro) linhas do DataFrame.

# %%
df.tail(4)
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 1048571          2   51        97         2  ...       2        2
# 1048572          2   55        97         2  ...       2        2
# 1048573          2   28        97         2  ...       2        2
# 1048574          2   52        97         2  ...       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# 1048571             1              2               2        2              2
# 1048572             2              2               2        2              2
# ...

# %% [markdown]
# ## Exercício 2

# %% [markdown]
# ### a) Exiba os nomes das colunas do DataFrame.

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [USMER, MEDICAL_UNIT, SEX, PATIENT_TYPE, DATE_DIED, INTUBED, PNEUMONIA, AGE, PREGNANT, DIABETES, COPD, ASTHMA, INMSUPR, HIPERTENSION, OTHER_DISEASE, CARDIOVASCULAR, OBESITY, RENAL_CHRONIC, TOBACCO, CLASIFFICATION_FINAL, ICU]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### b) Verifique os tipos de dados presentes em cada coluna.

# %%
df.dtypes
# Out:
# USMER                    int64
# MEDICAL_UNIT             int64
# SEX                      int64
# PATIENT_TYPE             int64
# DATE_DIED               object
# INTUBED                  int64
# PNEUMONIA                int64
# AGE                      int64
# PREGNANT                 int64
# DIABETES                 int64
# COPD                     int64
# ASTHMA                   int64
# INMSUPR                  int64
# HIPERTENSION             int64
# OTHER_DISEASE            int64
# CARDIOVASCULAR           int64
# OBESITY                  int64
# RENAL_CHRONIC            int64
# TOBACCO                  int64
# CLASIFFICATION_FINAL     int64
# ICU                      int64
# dtype: object

# %% [markdown]
# ### c) Em alguns casos, pode ser necessário fazer conversões de tipo de dados adequadas. Por exemplo: um dado que deveria ser inteiro e foi lido como string. Pesquise como fazer esta conversão, caso necessária.

# %%
df['DATE_DIED'] = pd.to_datetime(df['DATE_DIED'], errors='coerce')
# Out:
# <ipython-input-44-6885c72ae949>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['DATE_DIED'] = pd.to_datetime(df['DATE_DIED'], errors='coerce')

# %%
df.dtypes
# Out:
# USMER                            int64
# MEDICAL_UNIT                     int64
# SEX                              int64
# PATIENT_TYPE                     int64
# DATE_DIED               datetime64[ns]
# INTUBED                          int64
# PNEUMONIA                        int64
# AGE                              int64
# PREGNANT                         int64
# DIABETES                         int64
# COPD                             int64
# ASTHMA                           int64
# INMSUPR                          int64
# HIPERTENSION                     int64
# OTHER_DISEASE                    int64
# CARDIOVASCULAR                   int64
# OBESITY                          int64
# RENAL_CHRONIC                    int64
# TOBACCO                          int64
# CLASIFFICATION_FINAL             int64
# ICU                              int64
# dtype: object

# %% [markdown]
# ## Exercício 3

# %% [markdown]
# ### a) Verifique se há valores ausentes (NaN) no DataFrame. Observe que alguns bancos de dados utilizam números para representar dados ausentes.

# %%
df.isna().any().any() | df.isin([97, 98, 99]).any().any()
# Out:
# True

# %% [markdown]
# ### b) Identifique as colunas que possuem valores ausentes.

# %%
df.isna().any() | df.isin([97, 98, 99]).any()
# Out:
# USMER                   False
# MEDICAL_UNIT            False
# SEX                     False
# PATIENT_TYPE            False
# DATE_DIED                True
# INTUBED                  True
# PNEUMONIA                True
# AGE                      True
# PREGNANT                 True
# DIABETES                 True
# COPD                     True
# ASTHMA                   True
# INMSUPR                  True
# HIPERTENSION             True
# OTHER_DISEASE            True
# CARDIOVASCULAR           True
# OBESITY                  True
# RENAL_CHRONIC            True
# TOBACCO                  True
# CLASIFFICATION_FINAL    False
# ICU                      True
# dtype: bool

# %% [markdown]
# ### c) Identifique e conte quantas linhas possuem valores ausentes.

# %%
(df.isna() | df.isin([97, 98, 99])).any(axis=1).sum()
# Out:
# 1024766

# %% [markdown]
# ### d) Discuta uma decisão apropriada para lidar com os valores ausentes. Por exemplo, preencher com média, mediana ou remover as linhas. E em alguns casos pode até mesmo ser necessário remover uma coluna (caso ela tem um percentual muito alto de valores nulos).

# %%
# discutido com Guilherme

# %% [markdown]
# ## Exercício 4

# %% [markdown]
# ### a) Realize uma análise estatística básica do DataFrame, exibindo medidas como média, mediana, desvio padrão, etc.

# %%
df.describe()
# Out:
#               USMER  MEDICAL_UNIT           SEX  PATIENT_TYPE       INTUBED  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   1.632194e+00  8.980565e+00  1.499259e+00  1.190765e+00  7.952288e+01
# std    4.822084e-01  3.723278e+00  4.999997e-01  3.929041e-01  3.686889e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  4.000000e+00  1.000000e+00  1.000000e+00  9.700000e+01
# 50%    2.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  9.700000e+01
# 75%    2.000000e+00  1.200000e+01  2.000000e+00  1.000000e+00  9.700000e+01
# max    2.000000e+00  1.300000e+01  2.000000e+00  2.000000e+00  9.900000e+01
#
#           PNEUMONIA           AGE      PREGNANT      DIABETES          COPD  \
# count  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06  1.048575e+06
# mean   3.346831e+00  4.179410e+01  4.976558e+01  2.186404e+00  2.260569e+00
# ...

# %% [markdown]
# ### b) Identifique a coluna que possui o maior valor máximo e a coluna com o menor valor mínimo

# %%
print("A coluna com maior valor máximo é: ", df[(df.columns[df.columns != 'DATE_DIED'])].max().idxmax())
# Out:
# A coluna com maior valor máximo é:  AGE

# %%
print("A coluna com menor valor mínimo é: ", df[(df.columns[df.columns != 'DATE_DIED'])].min().idxmin())
# Out:
# A coluna com menor valor mínimo é:  AGE

# %% [markdown]
# ## Exercício 5

# %% [markdown]
# ### a) Crie uma nova coluna no DataFrame que represente a taxa de letalidade do COVID, calculada como o número de óbitos dividido pelo número de casos confirmados, multiplicado por 100.

# %%
casos_confirmados = df['CLASIFFICATION_FINAL'].isin([1, 2, 3]).sum()

# %%
obitos = (df['DATE_DIED'].notnull()).sum()

# %%
taxa_obito = (obitos/casos_confirmados)*100

# %%
df['TAXA_OBITO'] = taxa_obito

# %% [markdown]
# ### b) Exiba as primeiras cinco linhas do DataFrame para verificar se a coluna foi adicionada corretamente.

# %%
df.head(5)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  PNEUMONIA  AGE  \
# 0      2             1    1             1 2020-03-05       97          1   65
# 1      2             1    2             1 2020-03-06       97          1   72
# 2      2             1    2             2 2020-09-06        1          2   55
# 3      2             1    1             1 2020-12-06       97          2   53
# 4      2             1    2             1 2020-06-21       97          2   68
#
#    PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0         2         2  ...        2             1              2
# 1        97         2  ...        2             1              2
# 2        97         1  ...        2             2              2
# 3         2         2  ...        2             2              2
# 4        97         1  ...        2             1              2
#
#    CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  TOBACCO  CLASIFFICATION_FINAL  ICU  \
# ...

# %% [markdown]
# ## Exercício 6

# %% [markdown]
# ### a) Realize uma filtragem no DataFrame para exibir apenas as linhas referentes aos pacientes que foram para casa.

# %%
df[df['PATIENT_TYPE'] == 1]
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  \
# 0            2             1    1             1 2020-03-05       97
# 1            2             1    2             1 2020-03-06       97
# 3            2             1    1             1 2020-12-06       97
# 4            2             1    2             1 2020-06-21       97
# 6            2             1    1             1        NaT       97
# ...        ...           ...  ...           ...        ...      ...
# 1048568      1            13    2             1        NaT       97
# 1048570      2            13    2             1        NaT       97
# 1048572      2            13    2             1        NaT       97
# 1048573      2            13    2             1        NaT       97
# 1048574      2            13    2             1        NaT       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# 0                1   65         2         2  ...        2             1
# ...

# %% [markdown]
# ### b) Verifique quantas linhas foram filtradas.

# %%
df[df['PATIENT_TYPE'] == 1].shape[0]
# Out:
# 848544

# %% [markdown]
# ### c) A partir desses dados filtrados, verifique se todos possuem o valor NULO (97, 98, 99) a coluna referente a 'intubados' e a coluna referente a UTI.

# %%
((df['PATIENT_TYPE'] == 2) & (df['INTUBED'].isin([97, 98, 99]))).all()
# Out:
# False

# %% [markdown]
# ### d) Repita o item (a) e (b) para os pacientes que foram hospitalizados.

# %%
df[df['PATIENT_TYPE'] == 1]
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  \
# 0            2             1    1             1 2020-03-05       97
# 1            2             1    2             1 2020-03-06       97
# 3            2             1    1             1 2020-12-06       97
# 4            2             1    2             1 2020-06-21       97
# 6            2             1    1             1        NaT       97
# ...        ...           ...  ...           ...        ...      ...
# 1048568      1            13    2             1        NaT       97
# 1048570      2            13    2             1        NaT       97
# 1048572      2            13    2             1        NaT       97
# 1048573      2            13    2             1        NaT       97
# 1048574      2            13    2             1        NaT       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# 0                1   65         2         2  ...        2             1
# ...

# %%
df[df['PATIENT_TYPE'] == 2].shape[0]
# Out:
# 200031

# %% [markdown]
# ### e) Conte qual o percentual de pacientes grávidas dentre as mulheres que foram hospitalizadas.

# %%
mulheres_hospitalizadas = ((df['SEX'] == 1) & (df['PATIENT_TYPE'] == 2)).sum()

# %%
mulheres_gravidas_hospitalizadas = ((df['SEX'] == 1) & (df['PREGNANT'] == 1) & (df['PATIENT_TYPE'] == 2)).sum()

# %%
taxa_gravidas_hospitalizadas = (mulheres_gravidas_hospitalizadas/mulheres_hospitalizadas)*100
print(taxa_gravidas_hospitalizadas)
# Out:
# 2.4141644030051634

# %% [markdown]
# ## Exercício 7

# %% [markdown]
# ### a) Ordene o DataFrame em ordem decrescente com base em uma coluna numérica de sua escolha.

# %%
df.sort_values('AGE', ascending=[False])
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  INTUBED  PNEUMONIA  \
# 690837      2            12    1             1       NaT       97          2
# 394735      2             9    2             1       NaT       97          1
# 676023      2            12    2             1       NaT       97          2
# 820255      2            12    1             1       NaT       97          2
# 911976      2            12    2             1       NaT       97          2
# ...       ...           ...  ...           ...       ...      ...        ...
# 374335      2             6    2             2       NaT        1          1
# 735859      1            12    2             2       NaT        2          1
# 308495      1             4    2             2       NaT        2          2
# 499588      1            12    2             1       NaT       97          2
# 963810      2            12    2             1       NaT       97          2
#
# ...

# %% [markdown]
# ### b) Exiba as primeiras 10 (dez) linhas do DataFrame ordenado.

# %%
df.sort_values('AGE', ascending=[False]).head(10)
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  PNEUMONIA  \
# 690837      2            12    1             1        NaT       97          2
# 394735      2             9    2             1        NaT       97          1
# 676023      2            12    2             1        NaT       97          2
# 820255      2            12    1             1        NaT       97          2
# 911976      2            12    2             1        NaT       97          2
# 690811      2            12    2             1        NaT       97          2
# 894486      2            12    1             1        NaT       97          2
# 815750      2            12    1             1        NaT       97          2
# 341763      1             6    1             1 2020-01-05       97          1
# 690256      2            12    2             1        NaT       97          2
#
#         AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %% [markdown]
# ### c) Agora selecione duas colunas numéricas de sua escolha e ordene o DataFrame em ordem decrescente pela primeira coluna e, em caso de empate, em ordem crescente da segunda coluna.

# %%
df.sort_values(['MEDICAL_UNIT', 'AGE'], ascending=[False,True])
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  DATE_DIED  INTUBED  \
# 1047942      2            13    1             2        NaT        2
# 1048434      1            13    1             1        NaT       97
# 1048078      1            13    2             1        NaT       97
# 1048079      1            13    1             1        NaT       97
# 1048092      1            13    2             2        NaT       99
# ...        ...           ...  ...           ...        ...      ...
# 132          2             1    2             1        NaT       97
# 1            2             1    2             1 2020-03-06       97
# 16           2             1    1             2        NaT        2
# 117          2             1    1             1        NaT       97
# 84           2             1    2             2        NaT        2
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# 1047942          2    0         2         2  ...        2             2
# ...

# %% [markdown]
# ### d) Agora verifique o resultado exibindo as primeiras 10 (dez) linhas do DataFrame ordenado por duas colunas.

# %%
df.sort_values(['MEDICAL_UNIT', 'AGE'], ascending=[False,True]).head(10)
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  INTUBED  PNEUMONIA  \
# 1047942      2            13    1             2       NaT        2          2
# 1048434      1            13    1             1       NaT       97          2
# 1048078      1            13    2             1       NaT       97         99
# 1048079      1            13    1             1       NaT       97         99
# 1048092      1            13    2             2       NaT       99          1
# 1048103      2            13    1             2       NaT        2          2
# 1048124      1            13    2             2       NaT       99         99
# 1048128      1            13    2             2       NaT       99         99
# 1048155      1            13    2             2       NaT       99         99
# 1048159      1            13    1             2       NaT       99         99
#
#          AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %% [markdown]
# ## Exercício 8

# %% [markdown]
# ### a) Agrupe os dados por uma determinada coluna e calcule a soma, média e contagem de outra coluna numérica.

# %% [markdown]
# ### b) Exiba o resultado do agrupamento de forma organizada.

# %%
df.groupby('CLASIFFICATION_FINAL')['AGE'].agg(['sum', 'mean', 'count'])
# Out:
#                            sum       mean   count
# CLASIFFICATION_FINAL
# 1                       375991  43.714801    8601
# 2                       115399  62.344138    1851
# 3                     17221038  45.137141  381527
# 4                       130622  41.839206    3122
# 5                      1083105  41.512591   26091
# 6                      5068862  39.559380  128133
# 7                     19829234  39.718045  499250

# %% [markdown]
# ## Exercício 9

# %% [markdown]
# ### a) Utilize a função pivot_table para criar uma tabela que resuma os dados de duas colunas do DataFrame.
# ### b) Exiba a tabela criada.

# %%
df.pivot_table(index='MEDICAL_UNIT', columns='PATIENT_TYPE', aggfunc='size')
# Out:
# PATIENT_TYPE       1      2
# MEDICAL_UNIT
# 1                127     24
# 2                120     49
# 3              14933   4242
# 4             223710  90695
# 5               5485   1759
# 6              25339  15245
# 7                584    307
# 8               6923   3476
# 9              29086   9030
# 10              4258   3615
# 11              4247   1330
# 12            533027  69968
# 13               705    291

# %% [markdown]
# ## Exercício 10

# %% [markdown]
# ### a) Salve o DataFrame final em um arquivo CSV para futuras referências.
# ### b) Verifique se consegue ler corretamente o arquivo salvo.

# %%
df.to_csv('dataframe_parte1.csv')
